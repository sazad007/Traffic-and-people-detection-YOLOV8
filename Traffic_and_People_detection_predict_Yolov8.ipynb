# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from ultralytics import YOLO
import cv2, os

# %%
model = YOLO('/content/drive/MyDrive/VisDrone/visdrone-yolov8.pt')

# %%
model.predict(
    source='nyc.mp4',
    save=True,
    conf=0.5
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/505) /content/nyc.mp4: 640x384 3 pedestrians, 12 cars, 1 truck, 2 buss, 162.9ms
# video 1/1 (frame 2/505) /content/nyc.mp4: 640x384 3 pedestrians, 11 cars, 1 truck, 1 bus, 156.4ms
# video 1/1 (frame 3/505) /content/nyc.mp4: 640x384 3 pedestrians, 12 cars, 1 truck, 1 bus, 162.5ms
# video 1/1 (frame 4/505) /content/nyc.mp4: 640x384 3 pedestrians, 12 cars, 1 bus, 143.4ms
# ...
